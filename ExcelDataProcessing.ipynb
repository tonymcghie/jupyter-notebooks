# %%
# required modules
import numpy as np
import requests
import json
from pprint import pprint
import sys
import pandas as pd
import pandas.io.sql as sql
import MySQLdb as mdb

# %%
# Assign spreadsheet filename to `file`
file = 'temp-data/python_excel_data_processing_tasq_dev.xlsx'

# Load spreadsheet
xl = pd.ExcelFile(file)

# Print the sheet names
#print(xl.sheet_names)

# Load data into dataframes
sample_data = xl.parse('SampleData')
analytes = xl.parse('Analytes')
tasq_cal = xl.parse('TASQ_cal')
raw_data = xl.parse('RawData')
#sample_data
analytes
#tasq_cal
#raw_data
# Out:
#                            Compound Abbreviation  RT(min)    Formula  \
# 0                          catechin          Cat     4.04   C15H14O6
# 1                  chlorogenic acid          CGA     4.15   C16H18O9
# 2                       epicatechin       epiCat     5.13   C15H14O6
# 3           kaempferol 3-rutinoside        K-rut     6.84  C27H30O15
# 4               neochlorogenic acid       neoCGA     2.97   C16H18O9
# 5                         phloretin          Phl     8.00   C15H14O5
# 6      phloretin-2'-O-xyloglucoside     Phlz-xyl     6.98  C26H32O14
# 7                        phloridzin         Phlz     7.45  C21H24O10
# 8                    procyanidin B1     ProCy B1     3.57  C30H26O12
# 9                    procyanidin B2     ProCy B2     4.74  C30H26O12
# 10                   procyanidin B5     ProCy B5     6.49  C30H26O12
# 11                        quercetin            Q     8.38   C15H10O7
# 12    quercetin 3-arabinopyranoside      Q-arapy     6.98  C20H18O11
# 13          quercetin 3-galactoside        Q-gal     6.55  C21H20O12
# 14            quercetin 3-glucoside        Q-glu     6.60  C21H20O12
# 15           quercetin 3-rhamnoside        Q-rha     7.11  C21H20O11
# 16           quercetin 3-rutinoside        Q-rut     6.43  C27H30O16
# 17             quercetin 3-xyloside        Q-xyl     6.80  C20H18O11
# 18  trans-4-p-coumaroyl quinic acid      4pCouQA     5.30   C16H18O8
#
#              CAS  Exact Mass  CAM_ID                      Equivalence  \
# 0       154-24-4    290.0790       4                         catechin
# 1       327-97-9    354.0951       1                 chlorogenic acid
# 2       490-49-0    290.0790       3                      epicatechin
# 3     17650-84-9    594.1585      72          kaempferol 3-rutinoside
# 4    202650-88-2    354.0951     228                 chlorogenic acid
# 5        60-82-2    274.0841     126                       phloridzin
# 6    145758-09-4    568.1792     134                       phloridzin
# 7        60-81-1    436.1370       2                       phloridzin
# 8     20315-25-7    578.1424     215                   procyanidin B2
# 9     29106-49-8    578.1424       9                   procyanidin B2
# 10    12798-57-1    578.1425     321                   procyanidin B2
# 11      117-39-5    302.0427     157                        quercetin
# 12    22255-13-6    434.0849     153           quercetin 3-rutinoside
# 13      482-36-0    464.0955       7           quercetin 3-rutinoside
# 14      482-35-9    464.0955     154           quercetin 3-rutinoside
# 15      522-12-3    448.1006       8           quercetin 3-rutinoside
# 16      153-18-4    610.1534       6           quercetin 3-rutinoside
# 17      549-32-6    434.0849     150           quercetin 3-rutinoside
# 18  1108200-72-1    338.1002    2433  trans-4-p-coumaroyl quinic acid
#
#     Unnamed: 8  Unnamed: 9         CAS.1                       Compound.1  \
# 0          NaN         NaN      154-24-4                         catechin
# 1          NaN         NaN      327-97-9                 chlorogenic acid
# 2          NaN         NaN      490-49-0                      epicatechin
# 3          NaN         NaN    17650-84-9          kaempferol 3-rutinoside
# 4          NaN         NaN   202650-88-2              neochlorogenic acid
# 5          NaN         NaN       60-82-2                        phloretin
# 6          NaN         NaN   145758-09-4     phloretin-2'-O-xyloglucoside
# 7          NaN         NaN       60-81-1                       phloridzin
# 8          NaN         NaN    20315-25-7                   procyanidin B1
# 9          NaN         NaN    29106-49-8                   procyanidin B2
# 10         NaN         NaN    12798-57-1                   procyanidin B5
# 11         NaN         NaN      117-39-5                        quercetin
# 12         NaN         NaN    22255-13-6    quercetin 3-arabinopyranoside
# 13         NaN         NaN      482-36-0          quercetin 3-galactoside
# 14         NaN         NaN      482-35-9            quercetin 3-glucoside
# 15         NaN         NaN      522-12-3           quercetin 3-rhamnoside
# 16         NaN         NaN      153-18-4           quercetin 3-rutinoside
# 17         NaN         NaN      549-32-6             quercetin 3-xyloside
# 18         NaN         NaN  1108200-72-1  trans-4-p-coumaroyl quinic acid
#
#     Formula.1  Exact Mass.1  CAM_ID.1
# 0    C15H14O6      290.0790         4
# 1    C16H18O9      354.0951         1
# 2    C15H14O6      290.0790         3
# 3   C27H30O15      594.1585        72
# 4    C16H18O9      354.0951       228
# 5    C15H14O5      274.0841       126
# 6   C26H32O14      568.1792       134
# 7   C21H24O10      436.1370         2
# 8   C30H26O12      578.1424       215
# 9   C30H26O12      578.1424         9
# 10  C30H26O12      578.1425       321
# 11   C15H10O7      302.0427       157
# 12  C20H18O11      434.0849       153
# 13  C21H20O12      464.0955         7
# 14  C21H20O12      464.0955       154
# 15  C21H20O11      448.1006         8
# 16  C27H30O16      610.1534         6
# 17  C20H18O11      434.0849       150
# 18   C16H18O8      338.1002      2433
